# %% [markdown]
# <a href="https://colab.research.google.com/github/Srivarshini67/Srivarshini55/blob/main/BigMarket_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bigmart Sales Analysis

# %%
import numpy as np
import pandas as pd

# Importing the required libraries for the Analysis of the project.

# %% [markdown]
# # Loading the Data

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Train.csv')

# %%
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Test.csv')

# %% [markdown]
# # Data Structure and Content

# %%
train.shape
# Shape function Helps us Identify how many rows and columns we have according to our data set
# Out:
# (8523, 12)

# %%
train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
train.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
train.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
train.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
train['Item_Type'].value_counts()
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
train['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
test.shape
# Shape function Helps us Identify how many rows and columns we have according to our data set
# Out:
# (5681, 11)

# %%
test.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
test.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
test.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5676    False
# 5677    False
# 5678    False
# 5679    False
# 5680    False
# Length: 5681, dtype: bool

# %%
test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
test.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
test['Item_Type'].value_counts()
# Out:
# Item_Type
# Snack Foods              789
# Fruits and Vegetables    781
# Household                638
# Frozen Foods             570
# Dairy                    454
# Baking Goods             438
# Canned                   435
# Health and Hygiene       338
# Meat                     311
# Soft Drinks              281
# Breads                   165
# Hard Drinks              148
# Starchy Foods            121
# Others                   111
# Breakfast                 76
# Seafood                   25
# Name: count, dtype: int64

# %%
test['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd

#importing the required libraries for the Analysis of the project.

# %% [markdown]
# # DATA STRUCTURE AND CONTENT

# %% [markdown]
# # DATA PREPROCESSING

# %%
train['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
train['Item_Fat_Content'].replace(['LF','low fat','reg'],['Low Fat','Low Fat','Regular'],inplace=True)

# %%
train['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
test['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64

# %%
test['Item_Fat_Content'].replace(['LF','low fat','reg'],['Low Fat','Low Fat','Regular'],inplace=True)

# %%
test['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    3668
# Regular    2013
# Name: count, dtype: int64

# %% [markdown]
# # Explaratory data Analysis

# %% [markdown]
# uni variate analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import colors

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Item_Fat_Content',data=train)
plt.xlabel('Item_Fat_Content')
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Item_Type',data=train)
plt.xlabel('Item_Type')
plt.show()

# %%
outletsize=train['Outlet_Size'].value_counts(normalize=True)*100
explode=(0.05,0.06,0.07)
colors=('orange','yellow','green')
plt.pie(outletsize,labels=outletsize.index,autopct='%1.1f%%',explode=explode,colors=colors)
plt.title('%outletsize')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Outlet_Type',data=train)
plt.xlabel('Outlet_Type')
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Outlet_Establishment_Year',data=train)
plt.xlabel('Outlet_Establishment_Year')
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Outlet_Location_Type',data=train)
plt.xlabel('Outlet_Location_Type')
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Outlet_Size',data=test)
plt.ylabel('Outlet_Size')
plt.show()

# %% [markdown]
# # TO HANDLE THE MISSING CATEGORICAL VALUE

# %% [markdown]
# To handle the outliers

# %%
  # To handle the missing and null values
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for col in train.columns:
    if train[col].dtypes=='objects':
      train[col]=le.fit_transform(train[col])

# %%
train['Outlet_Size'].dtypes
#display the data type of 'Outlet_Size' column
# Out:
# dtype('O')

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# create SimpleImputer object for mean imputation in the TRAIN SET
imputer_numeric = SimpleImputer(strategy='mean')  # Imputer for numeric columns

# select NUMERIC columns with missing values
numeric_cols_with_missing = ["Item_Weight"]

# impute missing values in selected NUMERIC columns
train[numeric_cols_with_missing] = imputer_numeric.fit_transform(train[numeric_cols_with_missing])

# Now handle the 'Outlet_Size' column which is categorical
imputer_categorical = SimpleImputer(strategy='most_frequent') # Use most frequent for categorical
train['Outlet_Size'] = imputer_categorical.fit_transform(train[['Outlet_Size']])[:, 0]

# %%
train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
le=LabelEncoder()
for col in test.columns:
    if test[col].dtypes=='objects':
      test[col]=le.fit_transform(test[col])

# %%
test['Outlet_Size'].dtypes
#display the data type of 'Outlet_Size' column
# Out:
# dtype('O')

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300          Regular         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
# Import necessary libraries
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# Apply label encoding to the 'Outlet_Size' column in the training set
le = LabelEncoder()
train['Outlet_Size'] = le.fit_transform(train['Outlet_Size'])

# Now apply

# %%
imputer=SimpleImputer(strategy='mean')
missing_columns=['Item_Weight','Outlet_Size'] # Fix the typo here
train[missing_columns]=imputer.fit_transform(train[missing_columns])

# %%
test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# # Handling the outliers

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identify outliers')
plt.show()

# %%
number_columns=test.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identifying outliers')
plt.show()

# %%
q1=np.percentile(train['Item_Outlet_Sales'],25)
q3=np.percentile(train['Item_Outlet_Sales'],75)
iqr=q3-q1
print('q1',q1)
print('q3',q3)
print('IQR',iqr)
# Out:
# q1 834.2474
# q3 3101.2964
# IQR 2267.049

# %%
upperlimit=q3+1.5*iqr
lowerlimit=q1-1.5*iqr
print('upperlimit',upperlimit)
print('lowerlimit',lowerlimit)
# Out:
# upperlimit 6501.8699
# lowerlimit -2566.3261

# %% [markdown]
# #Cube transformation

# %%
train['Outlet_Sales_Cube']=np.cbrt(train['Item_Outlet_Sales'])

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identify outliers')
plt.show()

# %% [markdown]
# # Square Transformation

# %%
train['Outlet_Sales_Square']=np.cbrt(train['Item_Outlet_Sales'])

# %%
sns.distplot(a=train['Outlet_Sales_Square'],kde=True ,rug=True)
# Out:
# <ipython-input-249-5632d49b9e2c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Outlet_Sales_Square'],kde=True ,rug=True)
# <Axes: xlabel='Outlet_Sales_Square', ylabel='Density'>

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identify outliers')
plt.show()

# %% [markdown]
# # Bivarate Analysis

# %%
sns.distplot(a=train['Item_Outlet_Sales'],kde=True ,rug=True)
# Out:
# <ipython-input-251-2c7d3778c2e2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Item_Outlet_Sales'],kde=True ,rug=True)
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
sns.distplot(a=train['Outlet_Sales_Cube'],kde=True ,rug=True)
# Out:
# <ipython-input-252-ca45caa581af>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Outlet_Sales_Cube'],kde=True ,rug=True)
# <Axes: xlabel='Outlet_Sales_Cube', ylabel='Density'>

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Item_Outlet_Sales',y='Item_Type',data=train).set(title='Outlet sales vs Item type')
plt.xlabel('Item_Outlet_Sales')
plt.ylabel('Item_Type')
plt.show()

# %% [markdown]
# # Multivarient analysis

# %%
# Subset the dataset to include only the relevant numerical columns
subset = train[['Item_Weight', 'Item_Visibility', 'Item_MRP',
             'Outlet_Establishment_Year', 'Outlet_Sales_Cube', 'Item_Outlet_Sales']] # Removed string columns

# Calculate the correlation matrix
corr=subset.corr()

# Create a mask for the upper triangle of the heatmap
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the figure and axis objects
fig, ax = plt.subplots(figsize=(10, 8))

# Generate the heatmap with green and white colors
sns.heatmap(corr, mask=mask, annot=True, cmap=sns.diverging_palette(20, 220, n=200),
            center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# Set the title and labels for the plot
ax.set_title("Correlation Heatmap", fontsize=18)
ax.set_xlabel("Features", fontsize=14)
ax.set_ylabel("Features", fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year  Outlet_Size Outlet_Location_Type  \
# 0                       1999          1.0               Tier 1
# 1                       2009          1.0               Tier 3
# ...

# %%
# Check if 'Outlet_Establishment_Year' column exists in the DataFrame
if 'Outlet_Establishment_Year' in train.columns:
    train['Outlet_Age'] = train['Outlet_Establishment_Year'].apply(lambda year: 2024 - year)
else:
    print("Column 'Outlet_Establishment_Year' not found. Please check your data loading or previous operations.")

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year  Outlet_Size Outlet_Location_Type  \
# 0                       1999          1.0               Tier 1
# 1                       2009          1.0               Tier 3
# ...

# %%
train=train.drop(['Item_Identifier','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Item_Weight'],axis=1) # Remove the specified columns from the 'train' DataFrame
# 'Outlet_Sales_square' has been removed from the list of columns to drop, as it likely does not exist
# These columns are dropped as they are not necessary for the analysis or modeling

# %%
train=train.drop(['Item_Visibility','Item_Outlet_Sales'],axis=1)

# %%
train.head()
# Out:
#   Item_Fat_Content              Item_Type  Item_MRP Outlet_Location_Type  \
# 0          Low Fat                  Dairy  249.8092               Tier 1
# 1          Regular            Soft Drinks   48.2692               Tier 3
# 2          Low Fat                   Meat  141.6180               Tier 1
# 3          Regular  Fruits and Vegetables  182.0950               Tier 3
# 4          Low Fat              Household   53.8614               Tier 3
#
#          Outlet_Type  Outlet_Sales_Cube  Outlet_Sales_Square  Outlet_Age
# 0  Supermarket Type1          15.515611            15.515611          25
# 1  Supermarket Type2           7.625576             7.625576          15
# 2  Supermarket Type1          12.800240            12.800240          25
# 3      Grocery Store           9.013888             9.013888          26
# 4  Supermarket Type1           9.982319             9.982319          37

# %%
from sklearn.preprocessing import LabelEncoder

# %%
x=train[['Item_Fat_Content','Item_Type','Item_MRP','Outlet_Type','Outlet_Age']]
y=train['Outlet_Sales_Cube']

# %%
x.shape
# Out:
# (8523, 5)

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300          Regular         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
test['Outlet_Age']=test['Outlet_Establishment_Year'].apply(lambda year:2024-year)

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300          Regular         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type  Outlet_Age
# ...

# %%
test=test.drop(['Item_Identifier','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Item_Weight',],axis=1)

# %%
test = test.drop(['Item_Visibility'], axis=1)

# %%
test.head()
# Out:
#   Item_Fat_Content    Item_Type  Item_MRP Outlet_Location_Type  \
# 0          Low Fat  Snack Foods  107.8622               Tier 1
# 1          Regular        Dairy   87.3198               Tier 2
# 2          Low Fat       Others  241.7538               Tier 3
# 3          Low Fat  Snack Foods  155.0340               Tier 2
# 4          Regular        Dairy  234.2300               Tier 3
#
#          Outlet_Type  Outlet_Age
# 0  Supermarket Type1          25
# 1  Supermarket Type1          17
# 2      Grocery Store          26
# 3  Supermarket Type1          17
# 4  Supermarket Type3          39

# %%
from sklearn.preprocessing import StandardScaler  # Import the StandardScaler class

# %%
x_test=test[['Item_Fat_Content','Item_Type','Item_MRP','Outlet_Location_Type','Outlet_Type','Outlet_Age']]# Select specific columns from the 'test' DataFrame to create the feature set 'x_test'
# These columns include 'Item_Fat_Content', 'Item_Type', 'Item_MRP', 'Outlet_Location_Type', 'Outlet_Type', and 'Outlet_Age'
x_test=test[['Item_Fat_Content','Item_Type','Item_MRP','Outlet_Location_Type','Outlet_Type','Outlet_Age']]

# %%
x_test.shape
# Out:
# (5681, 6)

# %%
scaler = StandardScaler()  # Now you can create an instance

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import pandas as pd

# Assuming 'test' is your original DataFrame
x_test = test[['Item_Fat_Content','Item_Type','Item_MRP','Outlet_Location_Type','Outlet_Type','Outlet_Age']]

# Identify columns with categorical data
categorical_cols = ['Item_Fat_Content', 'Item_Type', 'Outlet_Location_Type', 'Outlet_Type']

# Handle categorical features using OneHotEncoder
encoder = OneHotEncoder(handle_unknown='ignore')  # 'ignore' to handle new categories in unseen data
encoded_data = encoder.fit

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Assuming 'x' is your DataFrame with categorical columns
x_encoded = pd.get_dummies(x, columns=['Item_Fat_Content', 'Item_Type', 'Outlet_Type'])  # Convert categorical columns

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_encoded)  # Apply StandardScaler to the encoded DataFrame

# %%
x=pd.DataFrame(x)

# %%
print(type(x))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
x.head()
# Out:
#   Item_Fat_Content              Item_Type  Item_MRP        Outlet_Type  \
# 0          Low Fat                  Dairy  249.8092  Supermarket Type1
# 1          Regular            Soft Drinks   48.2692  Supermarket Type2
# 2          Low Fat                   Meat  141.6180  Supermarket Type1
# 3          Regular  Fruits and Vegetables  182.0950      Grocery Store
# 4          Low Fat              Household   53.8614  Supermarket Type1
#
#    Outlet_Age
# 0          25
# 1          15
# 2          25
# 3          26
# 4          37

# %%
print(type(x))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## MODEL BUILDING

# %%
from sklearn.linear_model import LinearRegression
# For evaluating the models using the metrics

# %%
from sklearn.metrics import r2_score as R2
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.model_selection import cross_val_score as CVS

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression # Import LinearRegression

# Assuming 'x' is your DataFrame with categorical columns
# ... (rest of your code)

# Define the linear regression model
lr = LinearRegression()

# ... (rest of your code)

# %%
import pickle

# %%
Bigmart= "BigMart_Analysis.sav"
pickle.dump(lr, open(Bigmart,'wb'))

# %% [markdown]
# SUMMARY

# %% [markdown]
# Using Machine Learning Algorithms we analysed the data and executed the output for sales.
